# %% [markdown]
# # **Cached clean tables**

# %% [markdown]
# ### Cached load

# %%
from home_credit.load import get_raw_columns_description

col_descs = get_raw_columns_description()
display(col_descs)
# Out:
#                                Table                    Row  \
# col_id
# 1       application_{train|test}.csv             SK_ID_CURR
# 2       application_{train|test}.csv                 TARGET
# 5       application_{train|test}.csv     NAME_CONTRACT_TYPE
# 6       application_{train|test}.csv            CODE_GENDER
# 7       application_{train|test}.csv           FLAG_OWN_CAR
# ...                              ...                    ...
# 217        installments_payments.csv  NUM_INSTALMENT_NUMBER
# 218        installments_payments.csv        DAYS_INSTALMENT
# 219        installments_payments.csv     DAYS_ENTRY_PAYMENT
# 220        installments_payments.csv         AMT_INSTALMENT
# 221        installments_payments.csv            AMT_PAYMENT
#
#                                               Description  \
# col_id
# 1                                ID of loan in our sample
# 2       Target variable (1 - client with payment diffi...
# ...

# %% [markdown]
# ### Filtering

# %%
display(col_descs[col_descs.Table.str.startswith("application")])
# Out:
#                                Table                         Row  \
# col_id
# 1       application_{train|test}.csv                  SK_ID_CURR
# 2       application_{train|test}.csv                      TARGET
# 5       application_{train|test}.csv          NAME_CONTRACT_TYPE
# 6       application_{train|test}.csv                 CODE_GENDER
# 7       application_{train|test}.csv                FLAG_OWN_CAR
# ...                              ...                         ...
# 120     application_{train|test}.csv   AMT_REQ_CREDIT_BUREAU_DAY
# 121     application_{train|test}.csv  AMT_REQ_CREDIT_BUREAU_WEEK
# 122     application_{train|test}.csv   AMT_REQ_CREDIT_BUREAU_MON
# 123     application_{train|test}.csv   AMT_REQ_CREDIT_BUREAU_QRT
# 124     application_{train|test}.csv  AMT_REQ_CREDIT_BUREAU_YEAR
#
#                                               Description Special
# col_id
# 1                                ID of loan in our sample    None
# ...
