# %% [markdown]
# # **Effet du seuil de décision**

# %% [markdown]
# # Seuil à 50 %
#
# C'est le seuil de la méthode `predict` par défaut.

# %%
from home_credit.load import load_prep_dataset
from home_credit.best_model_search import post_train_eval
import sklearn as skl

data_s = load_prep_dataset("train_baseline_10k")
scaler = skl.preprocessing.MinMaxScaler()
threshold = .5
post_train_eval(data_s, res, clf, scaler, threshold)
# Out:
# Post train eval with threshold of 50.0 %
# X : shape (307511, 788)	y class counts : (array([0., 1.]), array([282686,  24825], dtype=int64))
# Xs : shape (10000, 788)	ys class counts : (array([0., 1.]), array([9177,  823], dtype=int64))
# Xrs : shape (18354, 788)	yrs class counts : (array([0., 1.]), array([9177, 9177], dtype=int64))
# Xv : shape (297511, 788)	yv class counts : (array([0., 1.]), array([273509,  24002], dtype=int64))
# <style>.nb-Link {{
#         font-family: var(--jp-ui-font-family)!important;
#         font-size: var(--jp-ui-font-size1)!important;
#     }}</style><b>Figure</b> saved 🔗 <a href='C:\Users\franc\Projects\pepper_credit_scoring_tool\img/model_eval/roc_auc_and_confusion_mx_for_sample_10k_2023_05_05_16_36_11_698843.png')>roc_auc_and_confusion_mx_for_sample_10k_2023_05_05_16_36_11_698843.png</a>
# Validation set metrics
# ROC AUC: 0.6970198655234991
# Accuracy: 0.4832392751864637
# ARI: -0.011235479756910454
# Jaccard Index: 0.31859954393655
# Precision: 0.4832392751864637
# Recall: 0.4832392751864637
# F1: 0.4832392751864637
# F2: 0.4832392751864637
# F4: 0.4832392751864637
# F8: 0.4832392751864637
# F16: 0.4832392751864637
#
# Undersampled validation set metrics
# Original dataset shape Counter({0.0: 273509, 1.0: 24002})
# Resampled dataset shape Counter({0.0: 24002, 1.0: 24002})
# ROC AUC: 0.6957264383316222
# Accuracy: 0.6292808932588951
# ARI: 0.06683714781215702
# Jaccard Index: 0.45908814589665653
# Precision: 0.6292808932588951
# Recall: 0.6292808932588951
# F1: 0.6292808932588951
# F2: 0.6292808932588951
# F4: 0.6292808932588951
# F8: 0.6292808932588951
# F16: 0.6292808932588951
# <style>.nb-Link {{
#         font-family: var(--jp-ui-font-family)!important;
#         font-size: var(--jp-ui-font-size1)!important;
#     }}</style><b>Figure</b> saved 🔗 <a href='C:\Users\franc\Projects\pepper_credit_scoring_tool\img/model_eval/roc_auc_curve_for_validation_resampled_subset_fulltraining_2023_05_05_16_36_47_700219.png')>roc_auc_curve_for_validation_resampled_subset_fulltraining_2023_05_05_16_36_47_700219.png</a>
# <style>.nb-Link {{
#         font-family: var(--jp-ui-font-family)!important;
#         font-size: var(--jp-ui-font-size1)!important;
#     }}</style><b>Figure</b> saved 🔗 <a href='C:\Users\franc\Projects\pepper_credit_scoring_tool\img/model_eval/validation_resampled_subset_fulltraining_2023_05_05_16_36_48_726917.png')>validation_resampled_subset_fulltraining_2023_05_05_16_36_48_726917.png</a>

# %% [markdown]
# # Seuil à 66 %
#
# C'est l'inverse de ce qu'il faut faire, mais pour la démonstration : là les faux négatifs l'emportent sur les faux positifs, ce qui est le contraire de ce qui est recherché.

# %%
from home_credit.load import load_prep_dataset
from home_credit.best_model_search import post_train_eval
import sklearn as skl

data_s = load_prep_dataset("train_baseline_10k")
scaler = skl.preprocessing.MinMaxScaler()
threshold = .66
post_train_eval(data_s, res, clf, scaler, threshold)
# Out:
# Post train eval with threshold of 66.0 %
# X : shape (307511, 788)	y class counts : (array([0., 1.]), array([282686,  24825], dtype=int64))
# Xs : shape (10000, 788)	ys class counts : (array([0., 1.]), array([9177,  823], dtype=int64))
# Xrs : shape (18354, 788)	yrs class counts : (array([0., 1.]), array([9177, 9177], dtype=int64))
# Xv : shape (297511, 788)	yv class counts : (array([0., 1.]), array([273509,  24002], dtype=int64))
# <style>.nb-Link {{
#         font-family: var(--jp-ui-font-family)!important;
#         font-size: var(--jp-ui-font-size1)!important;
#     }}</style><b>Figure</b> saved 🔗 <a href='C:\Users\franc\Projects\pepper_credit_scoring_tool\img/model_eval/roc_auc_and_confusion_mx_for_sample_10k_2023_05_05_16_41_34_439857.png')>roc_auc_and_confusion_mx_for_sample_10k_2023_05_05_16_41_34_439857.png</a>
# Validation set metrics
# ROC AUC: 0.6970198655234991
# Accuracy: 0.4832392751864637
# ARI: -0.011235479756910454
# Jaccard Index: 0.31859954393655
# Precision: 0.4832392751864637
# Recall: 0.4832392751864637
# F1: 0.4832392751864637
# F2: 0.4832392751864637
# F4: 0.4832392751864637
# F8: 0.4832392751864637
# F16: 0.4832392751864637
#
# Undersampled validation set metrics
# Original dataset shape Counter({0.0: 273509, 1.0: 24002})
# Resampled dataset shape Counter({0.0: 24002, 1.0: 24002})
# ROC AUC: 0.6957264383316222
# Accuracy: 0.6292808932588951
# ARI: 0.06683714781215702
# Jaccard Index: 0.45908814589665653
# Precision: 0.6292808932588951
# Recall: 0.6292808932588951
# F1: 0.6292808932588951
# F2: 0.6292808932588951
# F4: 0.6292808932588951
# F8: 0.6292808932588951
# F16: 0.6292808932588951
# <style>.nb-Link {{
#         font-family: var(--jp-ui-font-family)!important;
#         font-size: var(--jp-ui-font-size1)!important;
#     }}</style><b>Figure</b> saved 🔗 <a href='C:\Users\franc\Projects\pepper_credit_scoring_tool\img/model_eval/roc_auc_curve_for_validation_resampled_subset_fulltraining_2023_05_05_16_42_08_594033.png')>roc_auc_curve_for_validation_resampled_subset_fulltraining_2023_05_05_16_42_08_594033.png</a>
# <style>.nb-Link {{
#         font-family: var(--jp-ui-font-family)!important;
#         font-size: var(--jp-ui-font-size1)!important;
#     }}</style><b>Figure</b> saved 🔗 <a href='C:\Users\franc\Projects\pepper_credit_scoring_tool\img/model_eval/validation_resampled_subset_fulltraining_2023_05_05_16_42_09_594748.png')>validation_resampled_subset_fulltraining_2023_05_05_16_42_09_594748.png</a>

# %% [markdown]
# # Seuil à 40 %

# %%
from home_credit.load import load_prep_dataset
from home_credit.best_model_search import post_train_eval
import sklearn as skl

data_s = load_prep_dataset("train_baseline_10k")
scaler = skl.preprocessing.MinMaxScaler()
threshold = .4
post_train_eval(data_s, res, clf, scaler, threshold)
# Out:
# Post train eval with threshold of 40.0 %
# X : shape (307511, 788)	y class counts : (array([0., 1.]), array([282686,  24825], dtype=int64))
# Xs : shape (10000, 788)	ys class counts : (array([0., 1.]), array([9177,  823], dtype=int64))
# Xrs : shape (18354, 788)	yrs class counts : (array([0., 1.]), array([9177, 9177], dtype=int64))
# Xv : shape (297511, 788)	yv class counts : (array([0., 1.]), array([273509,  24002], dtype=int64))
# <style>.nb-Link {{
#         font-family: var(--jp-ui-font-family)!important;
#         font-size: var(--jp-ui-font-size1)!important;
#     }}</style><b>Figure</b> saved 🔗 <a href='C:\Users\franc\Projects\pepper_credit_scoring_tool\img/model_eval/roc_auc_and_confusion_mx_for_sample_10k_2023_05_05_16_48_25_032874.png')>roc_auc_and_confusion_mx_for_sample_10k_2023_05_05_16_48_25_032874.png</a>
# Validation set metrics
# ROC AUC: 0.6970198655234991
# Accuracy: 0.4832392751864637
# ARI: -0.011235479756910454
# Jaccard Index: 0.31859954393655
# Precision: 0.4832392751864637
# Recall: 0.4832392751864637
# F1: 0.4832392751864637
# F2: 0.4832392751864637
# F4: 0.4832392751864637
# F8: 0.4832392751864637
# F16: 0.4832392751864637
#
# Undersampled validation set metrics
# Original dataset shape Counter({0.0: 273509, 1.0: 24002})
# Resampled dataset shape Counter({0.0: 24002, 1.0: 24002})
# ROC AUC: 0.6957264383316222
# Accuracy: 0.6292808932588951
# ARI: 0.06683714781215702
# Jaccard Index: 0.45908814589665653
# Precision: 0.6292808932588951
# Recall: 0.6292808932588951
# F1: 0.6292808932588951
# F2: 0.6292808932588951
# F4: 0.6292808932588951
# F8: 0.6292808932588951
# F16: 0.6292808932588951
# <style>.nb-Link {{
#         font-family: var(--jp-ui-font-family)!important;
#         font-size: var(--jp-ui-font-size1)!important;
#     }}</style><b>Figure</b> saved 🔗 <a href='C:\Users\franc\Projects\pepper_credit_scoring_tool\img/model_eval/roc_auc_curve_for_validation_resampled_subset_fulltraining_2023_05_05_16_49_02_747344.png')>roc_auc_curve_for_validation_resampled_subset_fulltraining_2023_05_05_16_49_02_747344.png</a>
# <style>.nb-Link {{
#         font-family: var(--jp-ui-font-family)!important;
#         font-size: var(--jp-ui-font-size1)!important;
#     }}</style><b>Figure</b> saved 🔗 <a href='C:\Users\franc\Projects\pepper_credit_scoring_tool\img/model_eval/validation_resampled_subset_fulltraining_2023_05_05_16_49_03_690425.png')>validation_resampled_subset_fulltraining_2023_05_05_16_49_03_690425.png</a>

# %% [markdown]
# # Seuil à 30 %
#
# On réduit encore la quantité de faux négatifs, mais en contrepartie, le nombre de faux positifs commence à dépasse le nombre de vrais négatifs, ce qui signifie que l'on se prive de plus de la moitié d'une clientèle de qualité.

# %%
from home_credit.load import load_prep_dataset
from home_credit.best_model_search import post_train_eval
import sklearn as skl

data_s = load_prep_dataset("train_baseline_10k")
scaler = skl.preprocessing.MinMaxScaler()
threshold = .3
post_train_eval(data_s, res, clf, scaler, threshold)
# Out:
# Post train eval with threshold of 30.0 %
# X : shape (307511, 788)	y class counts : (array([0., 1.]), array([282686,  24825], dtype=int64))
# Xs : shape (10000, 788)	ys class counts : (array([0., 1.]), array([9177,  823], dtype=int64))
# Xrs : shape (18354, 788)	yrs class counts : (array([0., 1.]), array([9177, 9177], dtype=int64))
# Xv : shape (297511, 788)	yv class counts : (array([0., 1.]), array([273509,  24002], dtype=int64))
# <style>.nb-Link {{
#         font-family: var(--jp-ui-font-family)!important;
#         font-size: var(--jp-ui-font-size1)!important;
#     }}</style><b>Figure</b> saved 🔗 <a href='C:\Users\franc\Projects\pepper_credit_scoring_tool\img/model_eval/roc_auc_and_confusion_mx_for_sample_10k_2023_05_05_16_24_56_286133.png')>roc_auc_and_confusion_mx_for_sample_10k_2023_05_05_16_24_56_286133.png</a>
# Validation set metrics
# ROC AUC: 0.6970198655234991
# Accuracy: 0.4832392751864637
# ARI: -0.011235479756910454
# Jaccard Index: 0.31859954393655
# Precision: 0.4832392751864637
# Recall: 0.4832392751864637
# F1: 0.4832392751864637
# F2: 0.4832392751864637
# F4: 0.4832392751864637
# F8: 0.4832392751864637
# F16: 0.4832392751864637
#
# Undersampled validation set metrics
# Original dataset shape Counter({0.0: 273509, 1.0: 24002})
# Resampled dataset shape Counter({0.0: 24002, 1.0: 24002})
# ROC AUC: 0.6957264383316222
# Accuracy: 0.6292808932588951
# ARI: 0.06683714781215702
# Jaccard Index: 0.45908814589665653
# Precision: 0.6292808932588951
# Recall: 0.6292808932588951
# F1: 0.6292808932588951
# F2: 0.6292808932588951
# F4: 0.6292808932588951
# F8: 0.6292808932588951
# F16: 0.6292808932588951
# <style>.nb-Link {{
#         font-family: var(--jp-ui-font-family)!important;
#         font-size: var(--jp-ui-font-size1)!important;
#     }}</style><b>Figure</b> saved 🔗 <a href='C:\Users\franc\Projects\pepper_credit_scoring_tool\img/model_eval/roc_auc_curve_for_validation_resampled_subset_fulltraining_2023_05_05_16_25_33_280739.png')>roc_auc_curve_for_validation_resampled_subset_fulltraining_2023_05_05_16_25_33_280739.png</a>
# <style>.nb-Link {{
#         font-family: var(--jp-ui-font-family)!important;
#         font-size: var(--jp-ui-font-size1)!important;
#     }}</style><b>Figure</b> saved 🔗 <a href='C:\Users\franc\Projects\pepper_credit_scoring_tool\img/model_eval/validation_resampled_subset_fulltraining_2023_05_05_16_25_34_352300.png')>validation_resampled_subset_fulltraining_2023_05_05_16_25_34_352300.png</a>

# %% [markdown]
# # Seuil à 20 %

# %%
from home_credit.load import load_prep_dataset
from home_credit.best_model_search import post_train_eval
import sklearn as skl

data_s = load_prep_dataset("train_baseline_10k")
scaler = skl.preprocessing.MinMaxScaler()
threshold = .2
post_train_eval(data_s, res, clf, scaler, threshold)
# Out:
# Post train eval with threshold of 20.0 %
# X : shape (307511, 788)	y class counts : (array([0., 1.]), array([282686,  24825], dtype=int64))
# Xs : shape (10000, 788)	ys class counts : (array([0., 1.]), array([9177,  823], dtype=int64))
# Xrs : shape (18354, 788)	yrs class counts : (array([0., 1.]), array([9177, 9177], dtype=int64))
# Xv : shape (297511, 788)	yv class counts : (array([0., 1.]), array([273509,  24002], dtype=int64))
# <style>.nb-Link {{
#         font-family: var(--jp-ui-font-family)!important;
#         font-size: var(--jp-ui-font-size1)!important;
#     }}</style><b>Figure</b> saved 🔗 <a href='C:\Users\franc\Projects\pepper_credit_scoring_tool\img/model_eval/roc_auc_and_confusion_mx_for_sample_10k_2023_05_05_16_55_31_458401.png')>roc_auc_and_confusion_mx_for_sample_10k_2023_05_05_16_55_31_458401.png</a>
# Validation set metrics
# ROC AUC: 0.6970198655234991
# Accuracy: 0.4832392751864637
# ARI: -0.011235479756910454
# Jaccard Index: 0.31859954393655
# Precision: 0.4832392751864637
# Recall: 0.4832392751864637
# F1: 0.4832392751864637
# F2: 0.4832392751864637
# F4: 0.4832392751864637
# F8: 0.4832392751864637
# F16: 0.4832392751864637
#
# Undersampled validation set metrics
# Original dataset shape Counter({0.0: 273509, 1.0: 24002})
# Resampled dataset shape Counter({0.0: 24002, 1.0: 24002})
# ROC AUC: 0.6957264383316222
# Accuracy: 0.6292808932588951
# ARI: 0.06683714781215702
# Jaccard Index: 0.45908814589665653
# Precision: 0.6292808932588951
# Recall: 0.6292808932588951
# F1: 0.6292808932588951
# F2: 0.6292808932588951
# F4: 0.6292808932588951
# F8: 0.6292808932588951
# F16: 0.6292808932588951
# <style>.nb-Link {{
#         font-family: var(--jp-ui-font-family)!important;
#         font-size: var(--jp-ui-font-size1)!important;
#     }}</style><b>Figure</b> saved 🔗 <a href='C:\Users\franc\Projects\pepper_credit_scoring_tool\img/model_eval/roc_auc_curve_for_validation_resampled_subset_fulltraining_2023_05_05_16_56_09_699021.png')>roc_auc_curve_for_validation_resampled_subset_fulltraining_2023_05_05_16_56_09_699021.png</a>
# <style>.nb-Link {{
#         font-family: var(--jp-ui-font-family)!important;
#         font-size: var(--jp-ui-font-size1)!important;
#     }}</style><b>Figure</b> saved 🔗 <a href='C:\Users\franc\Projects\pepper_credit_scoring_tool\img/model_eval/validation_resampled_subset_fulltraining_2023_05_05_16_56_10_703051.png')>validation_resampled_subset_fulltraining_2023_05_05_16_56_10_703051.png</a>

# %% [markdown]
# # Seuil à 10 %
#
# Ou comment ne jamais se tromper en n'ayant aucun client !

# %%
from home_credit.load import load_prep_dataset
from home_credit.best_model_search import post_train_eval
import sklearn as skl

data_s = load_prep_dataset("train_baseline_10k")
scaler = skl.preprocessing.MinMaxScaler()
threshold = .1
post_train_eval(data_s, res, clf, scaler, threshold)
# Out:
# Post train eval with threshold of 10.0 %
# X : shape (307511, 788)	y class counts : (array([0., 1.]), array([282686,  24825], dtype=int64))
# Xs : shape (10000, 788)	ys class counts : (array([0., 1.]), array([9177,  823], dtype=int64))
# Xrs : shape (18354, 788)	yrs class counts : (array([0., 1.]), array([9177, 9177], dtype=int64))
# Xv : shape (297511, 788)	yv class counts : (array([0., 1.]), array([273509,  24002], dtype=int64))
# <style>.nb-Link {{
#         font-family: var(--jp-ui-font-family)!important;
#         font-size: var(--jp-ui-font-size1)!important;
#     }}</style><b>Figure</b> saved 🔗 <a href='C:\Users\franc\Projects\pepper_credit_scoring_tool\img/model_eval/roc_auc_and_confusion_mx_for_sample_10k_2023_05_05_17_22_58_305641.png')>roc_auc_and_confusion_mx_for_sample_10k_2023_05_05_17_22_58_305641.png</a>
# Validation set metrics
# ROC AUC: 0.6970198655234991
# Accuracy: 0.4832392751864637
# ARI: -0.011235479756910454
# Jaccard Index: 0.31859954393655
# Precision: 0.4832392751864637
# Recall: 0.4832392751864637
# F1: 0.4832392751864637
# F2: 0.4832392751864637
# F4: 0.4832392751864637
# F8: 0.4832392751864637
# F16: 0.4832392751864637
#
# Undersampled validation set metrics
# Original dataset shape Counter({0.0: 273509, 1.0: 24002})
# Resampled dataset shape Counter({0.0: 24002, 1.0: 24002})
# ROC AUC: 0.6957264383316222
# Accuracy: 0.6292808932588951
# ARI: 0.06683714781215702
# Jaccard Index: 0.45908814589665653
# Precision: 0.6292808932588951
# Recall: 0.6292808932588951
# F1: 0.6292808932588951
# F2: 0.6292808932588951
# F4: 0.6292808932588951
# F8: 0.6292808932588951
# F16: 0.6292808932588951
# <style>.nb-Link {{
#         font-family: var(--jp-ui-font-family)!important;
#         font-size: var(--jp-ui-font-size1)!important;
#     }}</style><b>Figure</b> saved 🔗 <a href='C:\Users\franc\Projects\pepper_credit_scoring_tool\img/model_eval/roc_auc_curve_for_validation_resampled_subset_fulltraining_2023_05_05_17_23_26_835480.png')>roc_auc_curve_for_validation_resampled_subset_fulltraining_2023_05_05_17_23_26_835480.png</a>
# <style>.nb-Link {{
#         font-family: var(--jp-ui-font-family)!important;
#         font-size: var(--jp-ui-font-size1)!important;
#     }}</style><b>Figure</b> saved 🔗 <a href='C:\Users\franc\Projects\pepper_credit_scoring_tool\img/model_eval/validation_resampled_subset_fulltraining_2023_05_05_17_23_27_666056.png')>validation_resampled_subset_fulltraining_2023_05_05_17_23_27_666056.png</a>
