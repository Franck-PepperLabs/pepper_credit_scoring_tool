# %% [markdown]
# # **Extended `previous_application`**

# %% [markdown]
# # Table de base

# %%
from home_credit.tables import PreviousApplication

data = PreviousApplication.clean()

display(data)
# Out:
# CLEAN_PREVIOUS_APPLICATION  TARGET NAME_CONTRACT_TYPE  AMT_ANNUITY  \
# SK_ID_CURR SK_ID_PREV
# 9733       64415                 0     Consumer loans     1730.430
# 42593      49913                 0         Cash loans    25188.615
# 56504      33098                 0         Cash loans    15060.735
# 45086      1195                  0         Cash loans    47041.335
# 5446       14793                 0         Cash loans    31924.395
# ...                            ...                ...          ...
# 24335      6704                 -1     Consumer loans    14704.290
# 6955       63271                -1     Consumer loans     6622.020
# 52936      38192                 0     Consumer loans    11520.855
# 7101       33070                 0         Cash loans    18821.520
# 64604      59466                 0         Cash loans    16431.300
#
# CLEAN_PREVIOUS_APPLICATION  AMT_APPLICATION  AMT_CREDIT  AMT_DOWN_PAYMENT  \
# SK_ID_CURR SK_ID_PREV
# 9733       64415                    17145.0     17145.0               0.0
# 42593      49913                   607500.0    679671.0               NaN
# 56504      33098                   112500.0    136444.5               NaN
# 45086      1195                    450000.0    470790.0               NaN
# 5446       14793                   337500.0    404055.0               NaN
# ...                                     ...         ...               ...
# 24335      6704                    267295.5    311400.0               0.0
# 6955       63271                    87750.0     64291.5           29250.0
# 52936      38192                   105237.0    102523.5           10525.5
# 7101       33070                   180000.0    191880.0               NaN
# 64604      59466                   360000.0    360000.0               NaN
#
# CLEAN_PREVIOUS_APPLICATION  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# SK_ID_CURR SK_ID_PREV
# 9733       64415                    17145.0                   SATURDAY
# 42593      49913                   607500.0                   THURSDAY
# 56504      33098                   112500.0                    TUESDAY
# 45086      1195                    450000.0                     MONDAY
# 5446       14793                   337500.0                   THURSDAY
# ...                                     ...                        ...
# 24335      6704                    267295.5                  WEDNESDAY
# 6955       63271                    87750.0                    TUESDAY
# 52936      38192                   105237.0                     MONDAY
# 7101       33070                   180000.0                  WEDNESDAY
# 64604      59466                   360000.0                     SUNDAY
#
# CLEAN_PREVIOUS_APPLICATION  HOUR_APPR_PROCESS_START  \
# SK_ID_CURR SK_ID_PREV
# 9733       64415                                 15
# 42593      49913                                 11
# 56504      33098                                 11
# 45086      1195                                   7
# 5446       14793                                  9
# ...                                             ...
# 24335      6704                                  12
# 6955       63271                                 15
# 52936      38192                                 12
# 7101       33070                                  9
# 64604      59466                                 10
#
# CLEAN_PREVIOUS_APPLICATION  FLAG_LAST_APPL_PER_CONTRACT  ...  \
# SK_ID_CURR SK_ID_PREV                                    ...
# 9733       64415                                      1  ...
# 42593      49913                                      1  ...
# 56504      33098                                      1  ...
# 45086      1195                                       1  ...
# 5446       14793                                      1  ...
# ...                                                 ...  ...
# 24335      6704                                       1  ...
# 6955       63271                                      1  ...
# 52936      38192                                      1  ...
# 7101       33070                                      1  ...
# 64604      59466                                      1  ...
#
# CLEAN_PREVIOUS_APPLICATION  NAME_SELLER_INDUSTRY  CNT_PAYMENT  \
# SK_ID_CURR SK_ID_PREV
# 9733       64415                    Connectivity         12.0
# 42593      49913                             XNA         36.0
# 56504      33098                             XNA         12.0
# 45086      1195                              XNA         12.0
# 5446       14793                             XNA         24.0
# ...                                          ...          ...
# 24335      6704                        Furniture         30.0
# 6955       63271                       Furniture         12.0
# 52936      38192            Consumer electronics         10.0
# 7101       33070                             XNA         12.0
# 64604      59466                             XNA         48.0
#
# CLEAN_PREVIOUS_APPLICATION  NAME_YIELD_GROUP          PRODUCT_COMBINATION  \
# SK_ID_CURR SK_ID_PREV
# 9733       64415                      middle     POS mobile with interest
# 42593      49913                  low_action             Cash X-Sell: low
# 56504      33098                        high            Cash X-Sell: high
# 45086      1195                       middle          Cash X-Sell: middle
# 5446       14793                        high            Cash Street: high
# ...                                      ...                          ...
# 24335      6704                   low_normal   POS industry with interest
# 6955       63271                      middle   POS industry with interest
# 52936      38192                  low_normal  POS household with interest
# 7101       33070                  low_normal             Cash X-Sell: low
# 64604      59466                      middle          Cash X-Sell: middle
#
# CLEAN_PREVIOUS_APPLICATION DAYS_FIRST_DRAWING DAYS_FIRST_DUE  \
# SK_ID_CURR SK_ID_PREV
# 9733       64415                         -0.0           42.0
# 42593      49913                         -0.0          134.0
# 56504      33098                         -0.0          271.0
# 45086      1195                          -0.0          482.0
# 5446       14793                          NaN            NaN
# ...                                       ...            ...
# 24335      6704                          -0.0          508.0
# 6955       63271                         -0.0         1604.0
# 52936      38192                         -0.0         1457.0
# 7101       33070                         -0.0         1155.0
# 64604      59466                         -0.0         1163.0
#
# CLEAN_PREVIOUS_APPLICATION  DAYS_LAST_DUE_1ST_VERSION DAYS_LAST_DUE  \
# SK_ID_CURR SK_ID_PREV
# 9733       64415                               -300.0          42.0
# 42593      49913                               -916.0          -0.0
# 56504      33098                                -59.0          -0.0
# 45086      1195                                 152.0         182.0
# 5446       14793                                  NaN           NaN
# ...                                               ...           ...
# 24335      6704                                -362.0         358.0
# 6955       63271                               1274.0        1304.0
# 52936      38192                               1187.0        1187.0
# 7101       33070                                825.0         825.0
# 64604      59466                               -247.0         443.0
#
# CLEAN_PREVIOUS_APPLICATION DAYS_TERMINATION NFLAG_INSURED_ON_APPROVAL
# SK_ID_CURR SK_ID_PREV
# 9733       64415                       37.0                       0.0
# 42593      49913                       -0.0                       1.0
# 56504      33098                       -0.0                       1.0
# 45086      1195                       177.0                       1.0
# 5446       14793                        NaN                       NaN
# ...                                     ...                       ...
# 24335      6704                       351.0                       0.0
# 6955       63271                     1297.0                       0.0
# 52936      38192                     1181.0                       0.0
# 7101       33070                      817.0                       1.0
# 64604      59466                      423.0                       0.0
#
# [1670214 rows x 36 columns]

# %% [markdown]
# # Tables périphériques agrégées

# %% [markdown]
# ## **`pos_cash_balance`** étendue groupée par prêt

# %% [markdown]
# ## **`credit_card_balance`** étendue groupée par prêt

# %% [markdown]
# ## **`installments_payments`** étendue groupée par prêt

# %% [markdown]
# # Adjonction

# %%
import pandas as pd
from home_credit.tables import (
    PreviousApplication,
    POSCashBalance,
    CreditCardBalance,
    InstallmentsPayments
)

from home_credit.groupby import (
    get_bureau_loan_status,
    get_bureau_mean_loan_activity,
    get_bureau_loan_status_by_month,
    get_bureau_loan_activity_by_month,
    get_rle_bureau_loan_feature_variations
)

def get_extended_clean_bureau(
    include_status: bool = True,
    include_activity: bool = True,
    include_status_variation: bool = False,
    include_activity_variation: bool = False
) -> pd.DataFrame:
    pass
