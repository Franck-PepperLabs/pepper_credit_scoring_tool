# %% [markdown]
# # **Module `home_credit.applicant`**

# %% [markdown]
# ## Proto de `view_applicant_info`
#
# On commence là, mais on va en avoir besoin pour streamlit.

# %%
from home_credit.applicant import view_applicant_info

view_applicant_info(317181)
# Out:
# VIEW APPLICANT INFOS
#
# Applicant ID: 317181
#
# Person
# Sex: Female
# Age: 35.17 years
# Employed: 0.64 years
# Registered: 4.37 years
# Identity docs: 4.3 years
#
# Application
# Contract type: Revolving loans
# Co-contractor: None
# Process start: Friday at 14:00
#
# Financial statement
# Annual income: 202 500
# Loan         : 585 000
# Assets       : _
# Loan annuity : 29 250
# Debt ratio   : 14 %
# Loan term    : 20.0 years
#
# Contact
# Phones provided  : ✘ Mobile, ✘ Employer, ✔ Work, ✔ Home
# Mobile reachable : ✘
# Email provided   : ✔
#
# Income, education and occupation
# Income type: Commercial associate
# Education type: Higher education
# Occupation type: Accountants
# Organization type: Business Entity Type 2
#
# Family
# Family status: Unknown
# Number of family members: _
# Number of children: 0
#
# Housing
# Housing type: House / apartment
#
# Region
# Population indice: 0.031329
# Region rating: 2
# City rating: 2
#
# Daily commute to work
# ...

# %%
from home_credit.applicant import view_applicant_info

view_applicant_info(224393)
# Out:
# VIEW APPLICANT INFOS
#
# Applicant ID: 224393
#
# Person
# Sex: Female
# Age: 59.24 years
# Employed: 15.41 years
# Registered: 0.36 years
# Identity docs: 13.64 years
#
# Application
# Contract type: Cash loans
# Co-contractor: Unaccompanied
# Process start: Monday at 11:00
#
# Financial statement
# Annual income: 270 000
# Loan         : 385 164
# Assets       : 292 500
# Loan annuity : 16 321
# Debt ratio   : 6 %
# Loan term    : 23.6 years
#
# Contact
# Phones provided  : ✘ Mobile, ✘ Employer, ✔ Work, ✔ Home
# Mobile reachable : ✘
# Email provided   : ✔
#
# Income, education and occupation
# Income type: Commercial associate
# Education type: Secondary / secondary special
# Occupation type: Managers
# Organization type: Business Entity Type 2
#
# Family
# Family status: Single / not married
# Number of family members: 1.0
# Number of children: 0
#
# Housing
# Housing type: Municipal apartment
#
# Region
# Population indice: 0.0002529999999999
# Region rating: 2
# City rating: -1
# ...

# %%
from home_credit.applicant import view_applicant_info

view_applicant_info(100004)
# Out:
# VIEW APPLICANT INFOS
#
# Applicant ID: 100004
#
# Person
# Sex: Male
# Age: 52.15 years
# Employed: 0.62 years
# Registered: 11.66 years
# Identity docs: 6.93 years
#
# Application
# Contract type: Revolving loans
# Co-contractor: Unaccompanied
# Process start: Monday at 9:00
#
# Financial statement
# Annual income: 67 500
# Loan         : 135 000
# Assets       : 135 000
# Loan annuity : 6 750
# Debt ratio   : 10 %
# Loan term    : 20.0 years
#
# Contact
# Phones provided  : ✘ Mobile, ✘ Employer, ✘ Work, ✘ Home
# Mobile reachable : ✘
# Email provided   : ✔
#
# Income, education and occupation
# Income type: Working
# Education type: Secondary / secondary special
# Occupation type: Laborers
# Organization type: Government
#
# Family
# Family status: Single / not married
# Number of family members: 1.0
# Number of children: 0
#
# Housing
# Housing type: House / apartment
#
# Region
# Population indice: 0.010032
# Region rating: 2
# City rating: 2
#
# Daily commute to work
# ...
